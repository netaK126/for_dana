# %%
import numpy as np
import torch

# %%
train = "cryptojacker.train.csv"
test = "cryptojacker.test.csv"

X_train = np.loadtxt(train, delimiter=',', usecols=list(range(1, 7+1)))
y_train = np.loadtxt(test, delimiter=',', usecols=0).astype(np.int32)
#X_train = X_train[:, top_idx]
print(X_train.shape)
X_test = np.loadtxt(test, delimiter=',', usecols=list(range(1, 7+1)))
y_test = np.loadtxt(test, delimiter=',', usecols=0).astype(np.int32)
#X_test = X_test[:, top_idx]
print(X_test.shape)
# Out:
# (2800, 7)
# (1200, 7)

# %%
X_combined = np.concatenate((X_train, X_test), axis=0)
print((X_combined).shape)
X_train = X_train/np.max(X_combined,axis=0)
X_test = X_train/np.max(X_combined,axis=0)

train_data = torch.from_numpy(X_train.astype(np.float32))
train_labels = torch.from_numpy(y_train.astype(np.int32))

test_data = torch.from_numpy(X_test.astype(np.float32))
test_labels = torch.from_numpy(y_test.astype(np.int32))

print(train_data, train_data.size())
print(train_labels, train_labels.size())
print(train_data.mean(dim=0))
torch.save((train_data, train_labels), './train.pth')
print(test_data, test_data.size())
print(test_labels, test_labels.size())
print(test_data.mean(dim=0))
torch.save((test_data, test_labels),  './test.pth')
# Out:
# (4000, 7)
# tensor([[1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         ...,
#         [1.0000, 0.0000, 1.0000,  ..., 0.2173, 0.3616, 1.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [1.0000, 0.0000, 0.0000,  ..., 0.0691, 0.0804, 1.0000]]) torch.Size([2800, 7])
# tensor([1, 1, 0,  ..., 1, 0, 0], dtype=torch.int32) torch.Size([1200])
# tensor([0.5304, 0.3393, 0.0993, 0.0906, 0.0213, 0.0110, 0.3964])
# tensor([[1.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         ...,
#         [1.0000e+00, 0.0000e+00, 1.0000e+00,  ..., 1.2488e-09, 3.8738e-10,
#          1.0000e+00],
#         [0.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 0.0000e+00, 0.0000e+00,
#          0.0000e+00],
#         [1.0000e+00, 0.0000e+00, 0.0000e+00,  ..., 3.9699e-10, 8.6151e-11,
#          1.0000e+00]]) torch.Size([2800, 7])
# tensor([1, 1, 0,  ..., 1, 0, 0], dtype=torch.int32) torch.Size([1200])
# tensor([5.3036e-01, 3.3929e-01, 9.9286e-02, 2.3835e-03, 1.2231e-10, 1.1818e-11,
#         3.9643e-01])

# %%
# !dir
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 9CEC-D90E
#
#  Directory of c:\anan\code_privacy\datasets\crypto
#
# 26/02/2024  06:44    <DIR>          .
# 26/02/2024  06:12    <DIR>          ..
# 26/02/2024  06:36    <DIR>          .ipynb_checkpoints
# 26/02/2024  00:08           240,000 cryptojacker.test.csv
# 26/02/2024  00:08           560,000 cryptojacker.train.csv
# 26/02/2024  00:08               175 cryptojacker_featstd.csv
# 26/02/2024  00:08                93 cryptojacker_header.csv
# 26/02/2024  06:44             5,643 load_and_save.ipynb
# 26/02/2024  06:42            84,486 test.pth
# 26/02/2024  06:42            84,492 train.pth
#                7 File(s)        974,889 bytes
#                3 Dir(s)  718,925,217,792 bytes free
